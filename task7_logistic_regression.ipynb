# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:\\Users\\ayush\\OneDrive\\Desktop\\TASK6\\framingham.csv')
df.head(10)
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
# 5     0   43        2.0              0         0.0     0.0                0
# 6     0   63        1.0              0         0.0     0.0                0
# 7     0   45        2.0              1        20.0     0.0                0
# 8     1   52        1.0              0         0.0     0.0                0
# 9     1   43        1.0              1        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# ...

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
plt.figure(figsize=(18,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.lineplot(y='education',x='TenYearCHD',data=df)
# Out:
# <Axes: xlabel='TenYearCHD', ylabel='education'>

# %% [markdown]
# ## people with higher education has less risk

# %%
df['education']=df['education'].fillna(2)

# %%
df['cigsPerDay'].unique()
# Out:
# array([ 0., 20., 30., 23., 15.,  9., 10.,  5., 35., 43.,  1., 40.,  3.,
#         2., nan, 12.,  4., 18., 25., 60., 14., 45.,  8., 50., 13., 11.,
#         7.,  6., 38., 29., 17., 16., 19., 70.])

# %%
sns.histplot(df['cigsPerDay'])
# Out:
# <Axes: xlabel='cigsPerDay', ylabel='Count'>

# %%
df['cigsPerDay']=df['cigsPerDay'].fillna(9)

# %%
plt.figure(figsize=(18,6))
sns.barplot(x='age',y='totChol',data=df)
# Out:
# <Axes: xlabel='age', ylabel='totChol'>

# %%
df['totChol']=df['totChol'].fillna(236.721585)

# %%
sns.histplot(df['prevalentHyp'])
# Out:
# <Axes: xlabel='prevalentHyp', ylabel='Count'>

# %%
sns.histplot(df['BPMeds'])
# Out:
# <Axes: xlabel='BPMeds', ylabel='Count'>

# %%
df['BPMeds']=df['BPMeds'].fillna(0)

# %%
#sns.barplot(x='diaBP',y='BMI',data=df)
df[df['BMI'].isnull()]
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 97       0   40        2.0              0         0.0     0.0
# 294      0   47        1.0              1        25.0     0.0
# 705      0   45        3.0              0         0.0     0.0
# 1155     0   64        2.0              1         3.0     0.0
# 1161     0   47        2.0              0         0.0     0.0
# 1594     0   40        2.0              0         0.0     0.0
# 1604     1   40        2.0              1        20.0     0.0
# 1624     0   70        1.0              0         0.0     0.0
# 1747     0   51        1.0              0         0.0     0.0
# 1975     1   63        1.0              1        20.0     0.0
# 2048     0   35        2.0              0         0.0     0.0
# 2067     0   58        1.0              1         1.0     0.0
# 2091     1   65        1.0              0         0.0     0.0
# 2177     0   53        3.0              0         0.0     0.0
# ...

# %%
sns.histplot(df['BMI'])
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
df['BMI']=df['BMI'].fillna(25.802008)

# %%
df[df['heartRate'].isnull()]
# Out:
#      male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 689     1   64        1.0              1        18.0     0.0                0
#
#      prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 689             1         0    219.0  172.5   75.0  29.29        NaN     91.0
#
#      TenYearCHD
# 689           1

# %%
df.isnull().sum()
# Out:
# male                 0
# age                  0
# education            0
# currentSmoker        0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                  0
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
sns.histplot(df['glucose'])
# Out:
# <Axes: xlabel='glucose', ylabel='Count'>

# %%
df['glucose'].mean()
# Out:
# 81.96675324675324

# %%
df['glucose']=df['glucose'].fillna(81.96440633930891)

# %%
df=df.dropna(subset=['heartRate'])

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3389, 15)
# (848, 15)
# (3389,)
# (848,)

# %%
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# x_train = sc.fit_transform(x_train)
# x_test = sc.fit_transform(x_test)
# x_train

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# d:\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred = lr.predict(x_test)

# %%
print("Train Score: :" ,lr.score(x_train,y_train))
print("Test Score : " ,lr.score(x_test,y_test))
# Out:
# Train Score: : 0.8468574800826203
# Test Score :  0.8596698113207547

# %%
from sklearn.metrics import mean_absolute_error,accuracy_score

print("MSE :",mean_absolute_error(y_test,pred))
print("Accuracy_score :", accuracy_score(y_test,pred))
# Out:
# MSE : 0.1403301886792453
# Accuracy_score : 0.8596698113207547
